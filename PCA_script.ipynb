# %%
# Installing Pillow Libraries
# !pip install scikit-learn matplotlib Pillow
# Out:
# Requirement already satisfied: scikit-learn in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: matplotlib in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: Pillow in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (10.0.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: six>=1.5 in /Users/nitinshrinivas/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import os
from random import randrange
from matplotlib import pyplot as plt
from PIL import Image

# %%
cfw_dict = {
    'Amitabhbachan': 0,
    'AamirKhan': 1,
    'DwayneJohnson': 2,
    'AishwaryaRai': 3,
    'BarackObama': 4,
    'NarendraModi': 5,
    'ManmohanSingh': 6,
    'VladimirPutin': 7
}

opt = {
    'image_size': 32,
    'is_grayscale': False,
    'val_split': 0.75
}

# %%
def load_image(path):
    im = Image.open(path).convert('L' if opt['is_grayscale'] else 'RGB')
    im = im.resize((opt['image_size'],opt['image_size']))
    im = np.array(im)
    im = im/256
    return im

def display_images(imgs,classes,row=1,col=2,w=32,h=32):
    fig=plt.figure(figsize=(8, 8))
    for i in range(1, col*row +1):
        img = imgs[i-1]
        fig.add_subplot(row, col, i)
        
        if opt['is_grayscale']:
            plt.imshow(img , cmap='gray') 
        else:
            plt.imshow(img)
        
        plt.title("Class:{}".format(classes[i-1]))
        plt.axis('off')
    plt.show()

def load_data(dir_path):
    image_list = []
    y_list = []
    label_dict = cfw_dict
    for filename in sorted(os.listdir(dir_path)):
        if filename.endswith(".png"):
            im = load_image(os.path.join(dir_path,filename))
            y = filename.split('_')[0]
            y = label_dict[y] 
            image_list.append(im)
            y_list.append(y)
        else:
            continue
    image_list = np.array(image_list)
    y_list = np.array(y_list)
    print("Dataset shape:",image_list.shape)
    print("Label shape:",y_list.shape)

    return image_list,y_list

# %%
dirpath = 'SMAI-PCAdataset/IIIT-CFW/'
X,y = load_data(dirpath)
# Out:
# Dataset shape: (672, 32, 32, 3)
# Label shape: (672,)

# %%
N,H,W = X.shape[0:3]
C = 1 if opt['is_grayscale'] else X.shape[3]

ind = np.random.randint(0,y.shape[0],6)
display_images(X[ind,...],y[ind], row=2,col=3)
